# %%
hoten=input("Nhập họ và tên của mày: ")
print(f"Chào {hoten}! Để xem tương lai bạn thế nào nhé.")
n=int(input("Nhập tuổi của bạn: "))
def Tuoi(n):
    if 1<n<18:
        print("Bạn là kid.")
        return 0
    elif n==0:
        print("Bạn chưa được sinh ra mà?")
        return 0
    else:    
        return n+30
T=Tuoi(n)
if n>40:
        print(f"Bạn già rồi {hoten}. Hahahahahahaha")
elif T!=0:
        print(f"{hoten} à, sau 30 năm bạn sẽ {T} tuổi.")
